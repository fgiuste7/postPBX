# %% [markdown]
# ### This will take the results for a given ROI for each subject.
#
#
# Steps:
#
#     Generate list of all subjects  (glob equivalent)
#     Determine metadata for each subject (i.e. Male or Female... from CSV File.. need to generalize this...)
#     For each fdt_paths.nii.gz file we need to threshold it by a certain value (or divide?
#        THRESHOLD =  waytotal * [ 0.0001, 0.001, 0.01 ]
#
#        WAYTOTAL is a named output from pbx2.. but it's a single line text file... need to reach this text file
#        and the INTEGER output needs to become parameterized
#
#
# BASIC Workflow:
#     1) Find all subjects with ROI = [ L_Hypo ]
#     2) Threshold each fdt_paths.nii.gz with the waytotal
#         fslmaths --input <file> -thr <NUMBER>
#        Better yet use Threshold interface (which wraps fslmaths)
#         Try multiple thresholds...
#     3)  Dump thresholded values into a new cleaner directory? with SubjectID?  Use datasink...
#
#
#     MAGIC!! We will run fslmerge on these outputs... but to make life easy.. we will merge all the MALES into fileX and FEMALES into file Y... adn then concatenate those two files together... that way our GLM is MUCH easier.

# %%
from the unrestricted file. .  we want the following counts/stats/graphs/whatever


1)  Cleanest way for   dataInfo['SubjectID']['Gender']

1)   dataInfo['SubjectID']['allData']  == ENTIRE TREE for a subject... WILL BE DUPLICATED BELOW

    dataInfo['SubjectID']['Gender']  = Actual Values
        
    dataInfo['subjectID']['FreeSurferData'] = freesurfer data...
    
        curSub_freeSurferDataDict = {}
        for k,v in allItems:
            if k.starswith(FS):
                curSub_freeSurferDataSet['k'] = v
                
                
    FS_IntraCranial_Vol


    dataInfo['subjectID'][freeSurfer] = freeSurferData

    dataInfo['SubjectID']['HasFreeSurferData']
    dataInfo['SubjectID']['DTIAvailable'] = True/False  <<< THIS IS FROM THEM... IE DATA SHOULD EXIST
    dataInfo['SubjectID']['bedpostXDone'] = True/False  << THIS MEANS WE HAVE FINISHED PROCSESING IT...
    dataInfo['SubjectID']['3T_Full_MR_Compl']]   THIS SHOULD BE FROM THE ORIGINAL DATA SET.. WE CAN THING FIGURE OUT IF WE 
    ACTUALLY DOWNLOADED AND OR PROCSESED THE DATA
    
    
    
    
    within nipype container its 
    
    [/data/]/HCP_Data/HCP_BedpostData/
    
        THINGS IN THIS THAT ARE RELEVANT
        
            MNINonLinear  -- we want that to exist!! That has freesurfer results per patient and also xfsm we need
            
            
            T1w-->  Should contain a Diffusion and a Diffusion.bedpostX directory.. if the bedpostX directory exists, we ran tractography already or at least its running

# %%
DELIVERABLES


1 )  Total HCP Subjects that have 3T Data 

1)  number we have downloaded

1) number of we run bedpostX on 

1) Number we have FINISHED running bedpostX on

1)  Do a pieChart of Gender Breakdown    ratio of male/female  
      Plot # in Data Set total, ads well as number we have COMPLETED data on...
    
    
Also... interactor for FREESURFER Results-- for now just graph 

L_HippocampalVolume vs Right Hippocampal Volume for MAles/Females 


Bonus Work--- maybe try a 2D or 3D Visualization of at least the REGION from PYSURFER??  Just because it's cool


YES---


ALSO DO HYPOTHALAMUS!!! 



AND IN THE FUTURE.. we will then layer in our FA Values per Region  MD Values per Region, etc etc etc
